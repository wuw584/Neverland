# %%
import numpy as np
import matplotlib.pyplot as plt
import datetime
import glob
import pandas as pd
import os
from scipy import signal
from obspy import Stream, Trace
import gc

from nptdms import TdmsFile
from DasTools import DasPrep as dp

import pyproj

from multiprocessing import Pool
from functools import partial

from das2sac_batch_run_parallel_func import das_processing, get_das_file_time, das_st_write_sac

# %%
datapath =  'L:\\anyuan_mine_2\\'
sacpath = 'L:\\anyuan_mine_2_sac\\'
datafile = glob.glob(datapath+'*.h5')
datafile.sort()

fname_format = datapath + 'anyuan_GL_5m_frq_1kHz_sp_1m_UTC_%Y%m%d_%H%M%S.%f.h5'
fname_npdatetime = np.array([np.datetime64(datetime.datetime.strptime(x, fname_format),'us') for x in datafile])
fname_datetime = np.array([datetime.datetime.strptime(x, fname_format) for x in datafile])

if not os.path.exists(sacpath):  os.makedirs(sacpath)

    
metadata = dp.read_das(datafile[len(datafile)//2], metadata=True)

for key in metadata.keys():
    print(key, ':', metadata[key])
    

dt = metadata['dt']
nt = metadata['nt']
file_len = dt*nt

ch1 = 90
ch2 = 1442 
das_ch_id = np.arange(ch1, ch2)

print(dt,nt, file_len)
# Out:
# dt : 0.001
# nt : 60000
# dx : 1.02095198631
# nch : 1472
# GL : 5.0
# headers : {'AcquisitionDescription': b'', 'AcquisitionId': b'd6fdc77a-ae5f-1b30-3b90-653f4d3243ef', 'FacilityId': array([b'TBD'],
#       dtype='|S3'), 'GaugeLength': 5.0, 'GaugeLength.uom': b'm', 'MaximumFrequency': 500.0, 'MaximumFrequency.uom': b'Hz', 'MeasurementStartTime': b'2023-09-01T07:09:48.193749+00:00', 'MinimumFrequency': 0.0, 'MinimumFrequency.uom': b'Hz', 'NumberOfLoci': 1472, 'PulseRate': 16000.0, 'PulseRate.uom': b'Hz', 'PulseWidth': 25.0, 'PulseWidth.uom': b'ns', 'ServiceCompanyName': b'Silixa', 'SpatialSamplingInterval': 1.0209519863128662, 'SpatialSamplingInterval.uom': b'm', 'StartLocusIndex': 0, 'TriggeredMeasurement': False, 'schemaVersion': b'2.1', 'uuid': b'2e63b005-3ece-493b-a723-e0a41856f9f5'}
# 0.001 60000 60.0

# %%
def get_continuous_segments(fname_datetime, file_len, tol):
    fname_datetime_diff = np.diff(fname_datetime)
    file_len_timedelta = datetime.timedelta(seconds=file_len*1.0001)
    segment_diff = np.where(fname_datetime_diff > file_len_timedelta)[0]  # define continuous segments by no files seperated more than the file length (15s)
    segment_start = np.r_[0, segment_diff + 1]
    segment_end = np.r_[segment_diff, len(fname_datetime) - 1]

    segment_start_datetime = fname_datetime[segment_start] + file_len_timedelta * 1.5 # shift to later by 1.5 file length to give buffer for rolling 
    segment_end_datetime = fname_datetime[segment_end] - file_len_timedelta * 1.5  # shift to earlier by 1.5 file length to give buffer for rolling 

    continuous_segment_size = np.array([x.total_seconds() for x in (segment_end_datetime - segment_start_datetime)])
    
    segment_choose = np.where(continuous_segment_size > tol)[0] 
    return segment_start_datetime[segment_choose], segment_end_datetime[segment_choose], continuous_segment_size[segment_choose]


segment_start_datetime, segment_end_datetime, continuous_segment_size = get_continuous_segments(fname_datetime, file_len, tol=10*60) # segments lasting more than 20 min
print(continuous_segment_size)
# Out:
# [   78599.982   123839.982   260579.982  1101719.982]

# %%
([(segment_start_datetime[i], segment_end_datetime[i])
  for i in range(len(segment_start_datetime))])
# Out:
# [(datetime.datetime(2023, 8, 8, 5, 48, 33, 238000),
#   datetime.datetime(2023, 8, 9, 3, 38, 33, 220000)),
#  (datetime.datetime(2023, 8, 9, 3, 43, 7, 702000),
#   datetime.datetime(2023, 8, 10, 14, 7, 7, 684000)),
#  (datetime.datetime(2023, 8, 10, 14, 13, 40, 637000),
#   datetime.datetime(2023, 8, 13, 14, 36, 40, 619000)),
#  (datetime.datetime(2023, 9, 1, 7, 11, 18, 202000),
#   datetime.datetime(2023, 9, 14, 1, 13, 18, 184000))]

# %%
for isegment in range(len(segment_start_datetime)):
    start_time, end_time = segment_start_datetime[isegment], segment_end_datetime[isegment]
    start_time = np.datetime64(start_time)
    end_time = np.datetime64(end_time)
    segment_size = end_time - start_time
    
    tmp = segment_size.astype('timedelta64[h]')
    print(f'Segment {isegment} : {tmp}')
    print(start_time)
    print(end_time)
    print(' ' )
# Out:
# Segment 0 : 21 hours
# 2023-08-08T05:48:33.238000
# 2023-08-09T03:38:33.220000
#
# Segment 1 : 34 hours
# 2023-08-09T03:43:07.702000
# 2023-08-10T14:07:07.684000
#
# Segment 2 : 72 hours
# 2023-08-10T14:13:40.637000
# 2023-08-13T14:36:40.619000
#
# Segment 3 : 306 hours
# 2023-09-01T07:11:18.202000
# 2023-09-14T01:13:18.184000

# %%
# %%time

nw = 'AY'
sta = 'DAS'
mlist = np.array([2,5])
nprocs = 20

chunk_size = np.timedelta64(7200, 's') #increment in hours
increment = np.timedelta64(120, 's') # one-time increment of data one thread holds


interval = increment * nprocs # total increment of data all threads hold
for isegment in range(len(segment_start_datetime)):
    
    start_time, end_time = segment_start_datetime[isegment], segment_end_datetime[isegment]
    start_time = np.datetime64(start_time)
    end_time = np.datetime64(end_time)
    segment_size = end_time - start_time
    chunk_num = segment_size // chunk_size + 1
    
    print('Segment id: %d'%(isegment))
    print('Segment size: %s'%(segment_size.astype('timedelta64[s]'))) 
    print('Regular chunk size: %s'%(chunk_size))
    print('Regular chunk number: %s'%(chunk_num - 1)) 
    print('Remainder chunk size: %s'%((segment_size % chunk_size).astype('timedelta64[s]')))
    
    print('nCPU number: %s'%(nprocs)) 
    print('Increment by each worker: %s'%(increment)) 
    print('Interval size: %s'%(interval)) 
    print('Interval number of regular chunks (if any): %s'%(chunk_size // interval))
    print('Interval number of the remainder chunk: %s'%(segment_size % chunk_size // interval))
    print(' ')
    
    segment_folder_path = sacpath + 'SAC-segment-' + ''.join(str(start_time.astype('datetime64[s]')).split(':')) 
    if not os.path.exists(segment_folder_path):
        os.makedirs(segment_folder_path)

    for ichunk in range(chunk_num):

        chunk_start_time = start_time + chunk_size * ichunk

        chunk_folder_path = os.path.join(segment_folder_path, 
                                         'SAC-chunk-' + ''.join(str(chunk_start_time.astype('datetime64[s]')).split(':')))

        if os.path.exists(chunk_folder_path):
            print('Chunk %d of Segment %d folder already exists: %s'%(ichunk, isegment, chunk_folder_path))
            print(' ')
            continue
            
        print('Chunk %d in Segment %d: %s'%(ichunk, isegment, chunk_folder_path))
        print('Start time of this chunk: %s'%(chunk_start_time.astype('datetime64[s]')))

        data = []
        interval_num = chunk_size // interval if ichunk < chunk_num-1 else segment_size % chunk_size // interval
        print('Total intervals in this Chunk: %d'%(interval_num))
        with Pool(processes=nprocs) as pool:
            for j in range(int(interval_num)):
                print('Working on Interval %d in Chunk %d in Segment %d'%(j, ichunk, isegment))
                increment_start_times = [ chunk_start_time + (interval * j) + (increment * i) for i in range(nprocs) ]
                res = pool.map(partial(das_processing, 
                                       interval=increment, 
                                       datafile=datafile, 
                                       datafile_time=fname_npdatetime, 
                                       ch1=ch1, ch2=ch2, mlist=mlist), 
                               increment_start_times)

                data.append(np.concatenate([res[i][0] for i in range(len(res))], axis=1))
                dt = res[0][1]
                del res

        if len(data) > 0:
            data = np.concatenate(data, axis=1)

            chunk_start_time_1 = chunk_start_time + increment
            datafile_arg_choose = np.where((fname_npdatetime>=chunk_start_time)&(fname_npdatetime<chunk_start_time_1))[0]
            chunk_start_time_from_file = fname_npdatetime[datafile_arg_choose][0]

            das_st = Stream()
            for ich in das_ch_id:

                data_ich = np.where(das_ch_id==ich)[0][0]

                tr = Trace(data=data[data_ich,:], header={'network':nw, 
                                                          'station': sta, 
                                                          'location':str(data_ich), 
                                                          'channel': str(ich),
                                                         'starttime':str(chunk_start_time_from_file), 
                                                          'delta':dt})

                das_st.append(tr)

            print('Writing to sac...')
            
            if not os.path.exists(chunk_folder_path):
                os.makedirs(chunk_folder_path)
            
            with Pool(processes=nprocs) as pool:
                pool.map(partial(das_st_write_sac, date_folder_path=chunk_folder_path, write_coordinates=False), das_st)

            del tr
            del das_st
            del data
        gc.collect()
        print(' ')
# Out:
# Segment id: 0
# Segment size: 78599 seconds
# Regular chunk size: 7200 seconds
# Regular chunk number: 10
# Remainder chunk size: 6599 seconds
# nCPU number: 20
# Increment by each worker: 120 seconds
# Interval size: 2400 seconds
# Interval number of regular chunks (if any): 3
# Interval number of the remainder chunk: 2
#
# Chunk 0 in Segment 0: M:\anyuan_mine_2_sac\SAC-segment-2023-08-08T054833\SAC-chunk-2023-08-08T054833
# Start time of this chunk: 2023-08-08T05:48:33
# Total intervals in this Chunk: 3
# Working on Interval 0 in Chunk 0 in Segment 0
# Working on Interval 1 in Chunk 0 in Segment 0
# Working on Interval 2 in Chunk 0 in Segment 0
# Writing to sac...
#
# Chunk 1 in Segment 0: M:\anyuan_mine_2_sac\SAC-segment-2023-08-08T054833\SAC-chunk-2023-08-08T074833
# Start time of this chunk: 2023-08-08T07:48:33
# Total intervals in this Chunk: 3
# Working on Interval 0 in Chunk 1 in Segment 0
# Working on Interval 1 in Chunk 1 in Segment 0
# Working on Interval 2 in Chunk 1 in Segment 0
# Writing to sac...
#
# Chunk 2 in Segment 0: M:\anyuan_mine_2_sac\SAC-segment-2023-08-08T054833\SAC-chunk-2023-08-08T094833
# Start time of this chunk: 2023-08-08T09:48:33
# Total intervals in this Chunk: 3
# Working on Interval 0 in Chunk 2 in Segment 0
# Working on Interval 1 in Chunk 2 in Segment 0
# Working on Interval 2 in Chunk 2 in Segment 0
# Writing to sac...
#
# Chunk 3 in Segment 0: M:\anyuan_mine_2_sac\SAC-segment-2023-08-08T054833\SAC-chunk-2023-08-08T114833
# Start time of this chunk: 2023-08-08T11:48:33
# Total intervals in this Chunk: 3
# Working on Interval 0 in Chunk 3 in Segment 0
# Working on Interval 1 in Chunk 3 in Segment 0
# Working on Interval 2 in Chunk 3 in Segment 0
# Writing to sac...
#
# Chunk 4 in Segment 0: M:\anyuan_mine_2_sac\SAC-segment-2023-08-08T054833\SAC-chunk-2023-08-08T134833
# Start time of this chunk: 2023-08-08T13:48:33
# Total intervals in this Chunk: 3
# Working on Interval 0 in Chunk 4 in Segment 0
# Working on Interval 1 in Chunk 4 in Segment 0
# Working on Interval 2 in Chunk 4 in Segment 0
# Writing to sac...
#
# Chunk 5 in Segment 0: M:\anyuan_mine_2_sac\SAC-segment-2023-08-08T054833\SAC-chunk-2023-08-08T154833
# Start time of this chunk: 2023-08-08T15:48:33
# Total intervals in this Chunk: 3
# Working on Interval 0 in Chunk 5 in Segment 0
# Working on Interval 1 in Chunk 5 in Segment 0
# Working on Interval 2 in Chunk 5 in Segment 0
# Writing to sac...
#
# Chunk 6 in Segment 0: M:\anyuan_mine_2_sac\SAC-segment-2023-08-08T054833\SAC-chunk-2023-08-08T174833
# Start time of this chunk: 2023-08-08T17:48:33
# Total intervals in this Chunk: 3
# Working on Interval 0 in Chunk 6 in Segment 0
# Working on Interval 1 in Chunk 6 in Segment 0
# Working on Interval 2 in Chunk 6 in Segment 0
# Writing to sac...
#
# Chunk 7 in Segment 0: M:\anyuan_mine_2_sac\SAC-segment-2023-08-08T054833\SAC-chunk-2023-08-08T194833
# Start time of this chunk: 2023-08-08T19:48:33
# Total intervals in this Chunk: 3
# Working on Interval 0 in Chunk 7 in Segment 0
# Working on Interval 1 in Chunk 7 in Segment 0
# Working on Interval 2 in Chunk 7 in Segment 0
# Writing to sac...
#
# Chunk 8 in Segment 0: M:\anyuan_mine_2_sac\SAC-segment-2023-08-08T054833\SAC-chunk-2023-08-08T214833
# Start time of this chunk: 2023-08-08T21:48:33
# Total intervals in this Chunk: 3
# Working on Interval 0 in Chunk 8 in Segment 0
# Working on Interval 1 in Chunk 8 in Segment 0
# Working on Interval 2 in Chunk 8 in Segment 0
# Writing to sac...
#
# Chunk 9 in Segment 0: M:\anyuan_mine_2_sac\SAC-segment-2023-08-08T054833\SAC-chunk-2023-08-08T234833
# Start time of this chunk: 2023-08-08T23:48:33
# Total intervals in this Chunk: 3
# Working on Interval 0 in Chunk 9 in Segment 0
# Working on Interval 1 in Chunk 9 in Segment 0
# Working on Interval 2 in Chunk 9 in Segment 0
# Writing to sac...
#
# Chunk 10 in Segment 0: M:\anyuan_mine_2_sac\SAC-segment-2023-08-08T054833\SAC-chunk-2023-08-09T014833
# Start time of this chunk: 2023-08-09T01:48:33
# Total intervals in this Chunk: 2
# Working on Interval 0 in Chunk 10 in Segment 0
# Working on Interval 1 in Chunk 10 in Segment 0
# Writing to sac...
#
# Segment id: 1
# Segment size: 123839 seconds
# Regular chunk size: 7200 seconds
# Regular chunk number: 17
# Remainder chunk size: 1439 seconds
# nCPU number: 20
# Increment by each worker: 120 seconds
# Interval size: 2400 seconds
# Interval number of regular chunks (if any): 3
# Interval number of the remainder chunk: 0
#
# Chunk 0 of Segment 1 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-09T034307\SAC-chunk-2023-08-09T034307
#
# Chunk 1 of Segment 1 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-09T034307\SAC-chunk-2023-08-09T054307
#
# Chunk 2 of Segment 1 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-09T034307\SAC-chunk-2023-08-09T074307
#
# Chunk 3 of Segment 1 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-09T034307\SAC-chunk-2023-08-09T094307
#
# Chunk 4 of Segment 1 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-09T034307\SAC-chunk-2023-08-09T114307
#
# Chunk 5 of Segment 1 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-09T034307\SAC-chunk-2023-08-09T134307
#
# Chunk 6 of Segment 1 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-09T034307\SAC-chunk-2023-08-09T154307
#
# Chunk 7 of Segment 1 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-09T034307\SAC-chunk-2023-08-09T174307
#
# Chunk 8 of Segment 1 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-09T034307\SAC-chunk-2023-08-09T194307
#
# Chunk 9 of Segment 1 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-09T034307\SAC-chunk-2023-08-09T214307
#
# Chunk 10 of Segment 1 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-09T034307\SAC-chunk-2023-08-09T234307
#
# Chunk 11 of Segment 1 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-09T034307\SAC-chunk-2023-08-10T014307
#
# Chunk 12 of Segment 1 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-09T034307\SAC-chunk-2023-08-10T034307
#
# Chunk 13 of Segment 1 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-09T034307\SAC-chunk-2023-08-10T054307
#
# Chunk 14 of Segment 1 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-09T034307\SAC-chunk-2023-08-10T074307
#
# Chunk 15 of Segment 1 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-09T034307\SAC-chunk-2023-08-10T094307
#
# Chunk 16 of Segment 1 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-09T034307\SAC-chunk-2023-08-10T114307
#
# Chunk 17 in Segment 1: M:\anyuan_mine_2_sac\SAC-segment-2023-08-09T034307\SAC-chunk-2023-08-10T134307
# Start time of this chunk: 2023-08-10T13:43:07
# Total intervals in this Chunk: 0
#
# Segment id: 2
# Segment size: 260579 seconds
# Regular chunk size: 7200 seconds
# Regular chunk number: 36
# Remainder chunk size: 1379 seconds
# nCPU number: 20
# Increment by each worker: 120 seconds
# Interval size: 2400 seconds
# Interval number of regular chunks (if any): 3
# Interval number of the remainder chunk: 0
#
# Chunk 0 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-10T141340
#
# Chunk 1 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-10T161340
#
# Chunk 2 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-10T181340
#
# Chunk 3 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-10T201340
#
# Chunk 4 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-10T221340
#
# Chunk 5 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-11T001340
#
# Chunk 6 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-11T021340
#
# Chunk 7 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-11T041340
#
# Chunk 8 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-11T061340
#
# Chunk 9 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-11T081340
#
# Chunk 10 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-11T101340
#
# Chunk 11 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-11T121340
#
# Chunk 12 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-11T141340
#
# Chunk 13 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-11T161340
#
# Chunk 14 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-11T181340
#
# Chunk 15 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-11T201340
#
# Chunk 16 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-11T221340
#
# Chunk 17 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-12T001340
#
# Chunk 18 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-12T021340
#
# Chunk 19 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-12T041340
#
# Chunk 20 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-12T061340
#
# Chunk 21 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-12T081340
#
# Chunk 22 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-12T101340
#
# Chunk 23 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-12T121340
#
# Chunk 24 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-12T141340
#
# Chunk 25 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-12T161340
#
# Chunk 26 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-12T181340
#
# Chunk 27 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-12T201340
#
# Chunk 28 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-12T221340
#
# Chunk 29 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-13T001340
#
# Chunk 30 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-13T021340
#
# Chunk 31 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-13T041340
#
# Chunk 32 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-13T061340
#
# Chunk 33 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-13T081340
#
# Chunk 34 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-13T101340
#
# Chunk 35 of Segment 2 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-13T121340
#
# Chunk 36 in Segment 2: M:\anyuan_mine_2_sac\SAC-segment-2023-08-10T141340\SAC-chunk-2023-08-13T141340
# Start time of this chunk: 2023-08-13T14:13:40
# Total intervals in this Chunk: 0
#
# Segment id: 3
# Segment size: 1101719 seconds
# Regular chunk size: 7200 seconds
# Regular chunk number: 153
# Remainder chunk size: 119 seconds
# nCPU number: 20
# Increment by each worker: 120 seconds
# Interval size: 2400 seconds
# Interval number of regular chunks (if any): 3
# Interval number of the remainder chunk: 0
#
# Chunk 0 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-01T071118
#
# Chunk 1 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-01T091118
#
# Chunk 2 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-01T111118
#
# Chunk 3 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-01T131118
#
# Chunk 4 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-01T151118
#
# Chunk 5 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-01T171118
#
# Chunk 6 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-01T191118
#
# Chunk 7 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-01T211118
#
# Chunk 8 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-01T231118
#
# Chunk 9 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-02T011118
#
# Chunk 10 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-02T031118
#
# Chunk 11 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-02T051118
#
# Chunk 12 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-02T071118
#
# Chunk 13 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-02T091118
#
# Chunk 14 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-02T111118
#
# Chunk 15 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-02T131118
#
# Chunk 16 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-02T151118
#
# Chunk 17 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-02T171118
#
# Chunk 18 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-02T191118
#
# Chunk 19 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-02T211118
#
# Chunk 20 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-02T231118
#
# Chunk 21 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-03T011118
#
# Chunk 22 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-03T031118
#
# Chunk 23 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-03T051118
#
# Chunk 24 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-03T071118
#
# Chunk 25 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-03T091118
#
# Chunk 26 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-03T111118
#
# Chunk 27 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-03T131118
#
# Chunk 28 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-03T151118
#
# Chunk 29 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-03T171118
#
# Chunk 30 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-03T191118
#
# Chunk 31 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-03T211118
#
# Chunk 32 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-03T231118
#
# Chunk 33 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-04T011118
#
# Chunk 34 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-04T031118
#
# Chunk 35 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-04T051118
#
# Chunk 36 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-04T071118
#
# Chunk 37 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-04T091118
#
# Chunk 38 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-04T111118
#
# Chunk 39 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-04T131118
#
# Chunk 40 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-04T151118
#
# Chunk 41 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-04T171118
#
# Chunk 42 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-04T191118
#
# Chunk 43 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-04T211118
#
# Chunk 44 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-04T231118
#
# Chunk 45 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-05T011118
#
# Chunk 46 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-05T031118
#
# Chunk 47 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-05T051118
#
# Chunk 48 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-05T071118
#
# Chunk 49 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-05T091118
#
# Chunk 50 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-05T111118
#
# Chunk 51 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-05T131118
#
# Chunk 52 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-05T151118
#
# Chunk 53 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-05T171118
#
# Chunk 54 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-05T191118
#
# Chunk 55 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-05T211118
#
# Chunk 56 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-05T231118
#
# Chunk 57 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-06T011118
#
# Chunk 58 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-06T031118
#
# Chunk 59 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-06T051118
#
# Chunk 60 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-06T071118
#
# Chunk 61 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-06T091118
#
# Chunk 62 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-06T111118
#
# Chunk 63 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-06T131118
#
# Chunk 64 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-06T151118
#
# Chunk 65 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-06T171118
#
# Chunk 66 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-06T191118
#
# Chunk 67 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-06T211118
#
# Chunk 68 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-06T231118
#
# Chunk 69 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-07T011118
#
# Chunk 70 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-07T031118
#
# Chunk 71 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-07T051118
#
# Chunk 72 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-07T071118
#
# Chunk 73 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-07T091118
#
# Chunk 74 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-07T111118
#
# Chunk 75 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-07T131118
#
# Chunk 76 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-07T151118
#
# Chunk 77 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-07T171118
#
# Chunk 78 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-07T191118
#
# Chunk 79 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-07T211118
#
# Chunk 80 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-07T231118
#
# Chunk 81 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-08T011118
#
# Chunk 82 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-08T031118
#
# Chunk 83 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-08T051118
#
# Chunk 84 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-08T071118
#
# Chunk 85 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-08T091118
#
# Chunk 86 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-08T111118
#
# Chunk 87 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-08T131118
#
# Chunk 88 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-08T151118
#
# Chunk 89 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-08T171118
#
# Chunk 90 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-08T191118
#
# Chunk 91 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-08T211118
#
# Chunk 92 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-08T231118
#
# Chunk 93 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-09T011118
#
# Chunk 94 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-09T031118
#
# Chunk 95 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-09T051118
#
# Chunk 96 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-09T071118
#
# Chunk 97 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-09T091118
#
# Chunk 98 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-09T111118
#
# Chunk 99 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-09T131118
#
# Chunk 100 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-09T151118
#
# Chunk 101 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-09T171118
#
# Chunk 102 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-09T191118
#
# Chunk 103 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-09T211118
#
# Chunk 104 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-09T231118
#
# Chunk 105 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-10T011118
#
# Chunk 106 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-10T031118
#
# Chunk 107 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-10T051118
#
# Chunk 108 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-10T071118
#
# Chunk 109 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-10T091118
#
# Chunk 110 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-10T111118
#
# Chunk 111 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-10T131118
#
# Chunk 112 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-10T151118
#
# Chunk 113 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-10T171118
#
# Chunk 114 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-10T191118
#
# Chunk 115 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-10T211118
#
# Chunk 116 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-10T231118
#
# Chunk 117 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-11T011118
#
# Chunk 118 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-11T031118
#
# Chunk 119 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-11T051118
#
# Chunk 120 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-11T071118
#
# Chunk 121 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-11T091118
#
# Chunk 122 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-11T111118
#
# Chunk 123 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-11T131118
#
# Chunk 124 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-11T151118
#
# Chunk 125 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-11T171118
#
# Chunk 126 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-11T191118
#
# Chunk 127 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-11T211118
#
# Chunk 128 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-11T231118
#
# Chunk 129 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-12T011118
#
# Chunk 130 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-12T031118
#
# Chunk 131 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-12T051118
#
# Chunk 132 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-12T071118
#
# Chunk 133 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-12T091118
#
# Chunk 134 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-12T111118
#
# Chunk 135 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-12T131118
#
# Chunk 136 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-12T151118
#
# Chunk 137 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-12T171118
#
# Chunk 138 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-12T191118
#
# Chunk 139 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-12T211118
#
# Chunk 140 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-12T231118
#
# Chunk 141 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-13T011118
#
# Chunk 142 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-13T031118
#
# Chunk 143 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-13T051118
#
# Chunk 144 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-13T071118
#
# Chunk 145 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-13T091118
#
# Chunk 146 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-13T111118
#
# Chunk 147 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-13T131118
#
# Chunk 148 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-13T151118
#
# Chunk 149 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-13T171118
#
# Chunk 150 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-13T191118
#
# Chunk 151 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-13T211118
#
# Chunk 152 of Segment 3 folder already exists: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-13T231118
#
# Chunk 153 in Segment 3: M:\anyuan_mine_2_sac\SAC-segment-2023-09-01T071118\SAC-chunk-2023-09-14T011118
# Start time of this chunk: 2023-09-14T01:11:18
# Total intervals in this Chunk: 0
#
# Wall time: 1h 4min 29s
